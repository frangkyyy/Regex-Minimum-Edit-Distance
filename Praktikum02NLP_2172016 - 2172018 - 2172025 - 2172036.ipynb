# %% [markdown]
# ## 2.1 Write regular expressions for the following languages

# %%
import re
import pandas as pd

# Read the CSV file
df = pd.read_csv('text.csv') #sumber data https://www.kaggle.com/code/abdmental01/emotions-analysis-gru-94/input

# Select the rows from index
df_selected = df.iloc[0:99]

# %% [markdown]
# ## 1. The set of all alphabetic strings

# %%
# Regular expression for all alphabetic strings
regex_1 = r'[a-zA-Z]+'

# Process each row of the selected range
for index, text in enumerate(texts):
    print(f"\nProcessing text {index+2}: {text}")  # Adjust index to match the original row numbers
    matches_1 = re.findall(regex_1, text)
    
    # Print the matches
    print(f"Alphabetic strings (regex 1): {matches_1}")
# Out:
# Processing text 2: i just feel really helpless and heavy hearted
# Alphabetic strings (regex 1): ['i', 'just', 'feel', 'really', 'helpless', 'and', 'heavy', 'hearted']
#
# Processing text 3: ive enjoyed being able to slouch about relax and unwind and frankly needed it after those last few weeks around the end of uni and the expo i have lately started to find myself feeling a bit listless which is never really a good thing
# Alphabetic strings (regex 1): ['ive', 'enjoyed', 'being', 'able', 'to', 'slouch', 'about', 'relax', 'and', 'unwind', 'and', 'frankly', 'needed', 'it', 'after', 'those', 'last', 'few', 'weeks', 'around', 'the', 'end', 'of', 'uni', 'and', 'the', 'expo', 'i', 'have', 'lately', 'started', 'to', 'find', 'myself', 'feeling', 'a', 'bit', 'listless', 'which', 'is', 'never', 'really', 'a', 'good', 'thing']
#
# Processing text 4: i gave up my internship with the dmrg and am feeling distraught
# ...

# %% [markdown]
# ## 2. The set of all lower case alphabetic strings ending in either a b

# %%
# Regular expression for lower-case alphabetic strings ending in either 'a' or 'b' at the end of a word
regex_2 = r'\b[a-z]*[ab]\b'

# Process each row of the selected range
for index, text in enumerate(texts):
    print(f"\nProcessing text {index+2}: {text}") 
    matches_2 = re.findall(regex_2, text)
    
    # Print the matches
    print(f"Lower-case alphabetic strings ending in 'a' or 'b' (regex 2): {matches_2}")
# Out:
# Processing text 2: i just feel really helpless and heavy hearted
# Lower-case alphabetic strings ending in 'a' or 'b' (regex 2): []
#
# Processing text 3: ive enjoyed being able to slouch about relax and unwind and frankly needed it after those last few weeks around the end of uni and the expo i have lately started to find myself feeling a bit listless which is never really a good thing
# Lower-case alphabetic strings ending in 'a' or 'b' (regex 2): ['a', 'a']
#
# Processing text 4: i gave up my internship with the dmrg and am feeling distraught
# Lower-case alphabetic strings ending in 'a' or 'b' (regex 2): []
#
# Processing text 5: i dont know i feel so lost
# Lower-case alphabetic strings ending in 'a' or 'b' (regex 2): []
#
# Processing text 6: i am a kindergarten teacher and i am thoroughly weary of my job after having taken the university entrance exam i suffered from anxiety for weeks as i did not want to carry on with my work studies were the only alternative
# ...

# %% [markdown]
# ## 3. The set of all strings from the alphabet a,b such that each a is immediately preceded by and immediately followed by a b

# %%
# Regular expression for strings where each 'a' is surrounded by 'b'
regex_3 = r'bab'

# Process each row of the selected range
for index, text in enumerate(texts):
    print(f"\nProcessing text {index+2}: {text}")  # Adjust index to match the original row numbers
    matches_3 = re.findall(regex_3, text)
    
    # Print the matches
    print(f"Strings where 'a' is surrounded by 'b' (regex 3): {matches_3}")
# Out:
# Processing text 2: i just feel really helpless and heavy hearted
# Strings where 'a' is surrounded by 'b' (regex 3): []
#
# Processing text 3: ive enjoyed being able to slouch about relax and unwind and frankly needed it after those last few weeks around the end of uni and the expo i have lately started to find myself feeling a bit listless which is never really a good thing
# Strings where 'a' is surrounded by 'b' (regex 3): []
#
# Processing text 4: i gave up my internship with the dmrg and am feeling distraught
# Strings where 'a' is surrounded by 'b' (regex 3): []
#
# Processing text 5: i dont know i feel so lost
# Strings where 'a' is surrounded by 'b' (regex 3): []
#
# Processing text 6: i am a kindergarten teacher and i am thoroughly weary of my job after having taken the university entrance exam i suffered from anxiety for weeks as i did not want to carry on with my work studies were the only alternative
# Strings where 'a' is surrounded by 'b' (regex 3): []
#
# ...
